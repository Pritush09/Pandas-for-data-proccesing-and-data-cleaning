# %% [markdown]
# #     How to read the tabular data

# %%
import pandas as pd

# %%
pd.options.display.max_rows =99
#help us to increase the field of view of the data tablen

# %%
#orders =pd.read_table('http://bit.ly/chiporders')#it also help us to read data directly from the url
#by default read_table assumed that our file is tab seperated 
#other thing it assumed that the first row is the header row

# %%
#orders.head()

# %%
#pd.read_table('http://bit.ly/movieusers',sep='|',header=None,names = ['user_id','age','gender','occupation','zip_code'])
#we need to tell the pandas that it is seperated by "|"
#header is the heading line
#it takes names instead of columns

# %% [markdown]
# # BONUS TIP
# these arguments are used to just ignore the lines which the user just have defined in its for the purpose of under standing
# skipfooter argument
# skiprows argument

# %% [markdown]
# # How to select a pandas Series from dataframe

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')# i had used table earlier 
#we can use read_csv as an option as csv by default seperate data by ,  csv = comma seperated values

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.head()

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
type(ufo['City'])
# Out:
# pandas.core.series.Series

# %%
#we can also use dot notion to get the same output 
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
 #if there is a space in the headers we simply cannot use the dot notation in such
    # case like the case given below
 #it also fails if two columns have the same headers example shape and shape reported

# %%
ufo['Colors Reported']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18236    NaN
# 18237    NaN
# 18238    NaN
# 18239    RED
# 18240    NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %% [markdown]
# # Bonus Tip

# %%
#If we want to create a new panda series in dataframe 
ufo['Location']=ufo.City + ", "+ufo.State

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %% [markdown]
# # Why Do Some pandas command ends with parenthesis
# #                 and other commands dont

# %%
ratings = pd.read_csv('http://bit.ly/imdbratings')

# %%
ratings
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
ratings.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
ratings.describe()
#it works as long as there is a numeric column in the dataset it will show the whole description of the numeric column as shown below
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
ratings.shape
# Out:
# (979, 6)

# %%
ratings.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# # methods are the one with the paranthesis
# # atributes are the one without the parenthsis

# %%
ratings.describe(include = ['object'])#we can also use it without giving any parameters
#it will now only describe only or the data types which are objects
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %% [markdown]
# # Bonus Tip

# %%
# if u want to to know the arguments it method or a function takes just take the pointer inside the paranthesis 
# and click shift + Tab so there is brief descripyion of the args that the the function or a method is taking and if  hit it
# for the 4th time in row then it will show u the whole argument u can pass into it

# %% [markdown]
# # How do i rename the column in the pandas dataframe

# %%
ufoo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufoo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufoo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufoo.rename(columns = {'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'},inplace=True)
#in this method we pass in the dictionary to rename the columns
# we wanted to
#inplace args specify that i want to make the changes in the underlying dataframe

# %%
ufoo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
# if i want to rename the every column names with the less typing 
ufoo_cols =['city','colors repoted','shape reported','state','time']

# %%
ufoo.columns = [ufoo_cols]

# %%
ufoo.head()
# Out:
#                    city colors repoted shape reported state             time
# 0                Ithaca            NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene            NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            NaN          LIGHT    NY  4/18/1933 19:00

# %%
# to do this directly while readind the data from the ur we can use names argument 
uffo = pd.read_csv('http://bit.ly/uforeports',names = ufoo_cols,header=0)
#header we can tell python that the the given row already has the names and then it wil over write it

# %%
uffo.head()
# Out:
#                    city colors repoted shape reported state             time
# 0                Ithaca            NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene            NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # Bonus Tips

# %%
# if u want to replace all the given spaces with under scores in the most efficient ways we can use a str method and replace 
# things we want to 
#.str.replace(' ','_') this is how we call a str method first defing it and defing the function we want to use 
uffo.columns = uffo.columns.str.replace(' ','_')

# %%
uffo.columns
# Out:
# Index(['city', 'colors_repoted', 'shape_reported', 'state', 'time'], dtype='object')

# %% [markdown]
# # how to remove the column from pandas dataframe

# %%
unfo = pd.read_csv("http://bit.ly/uforeports")

# %%
unfo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
unfo.shape
# Out:
# (18241, 5)

# %%
#axis = 0 is the row AXIS 1 u now know   ,   inplace means that we want it to occur inplace 
unfo.drop("Colors Reported",axis = 1,inplace= True)

# %%
unfo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
#deleted the columns using 
# unfo.drop(['State',"City"],axis=1,inplace=True)

# %%
unfo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # Bonus Tip

# %%
# WE can use this drop function for removing the rows also 
# the space place is if i want to remove the selected part of datframe which is of no use

# %%
unfo.drop([0,1] ,axis=0,inplace=True) #axis = 0 is default

# %%
unfo.head()
# Out:
#                    City Shape Reported State             Time
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00
# 5           Valley City           DISK    ND  9/15/1934 15:30
# 6           Crater Lake         CIRCLE    CA   6/15/1935 0:00

# %% [markdown]
# # how to sort a pandas dataframe or series

# %%
imdb1 = pd.read_csv("http://bit.ly/imdbratings")

# %%
imdb1.head()   # Shape is 979,6
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
imdb1.title.sort_values()  # it does not change the real data it ust change a copy of that
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
# if u want an dataframe to be return back then 
# it does not also change thde underlying data
imdb1.sort_values("duration")
# Out:
#      star_rating                              title content_rating      genre  \
# 389          8.0                             Freaks        UNRATED      Drama
# 338          8.0                Battleship Potemkin        UNRATED    History
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# ..           ...                                ...            ...        ...
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
# ...

# %% [markdown]
# # Bonus Tip

# %%
# if u wanna sort values by multiple columns just pass the column in form of list

# %% [markdown]
# # how do filter rows of a pandas dataframe by column values

# %%
imdb2 = pd.read_csv("http://bit.ly/imdbratings")

# %%
imdb2.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
imdb2.shape
# Out:
# (979, 6)

# %%
# filtering the data on thee basis of the movies that are above 200 min

# %%
# fisrtly to understand the direct method present in pandas we will break it into parts

# %%
boolean = []
for lenght in imdb2.duration:
    if lenght >= 200:
        boolean.append(True)
    else:
        boolean.append(False)

# %%
boolean[0:5]
# Out:
# [False, False, True, False, False]

# %%
len(boolean)
# Out:
# 979

# %%
# now we convert the boolean list into the pandas series 
is_long = pd.Series(boolean)

# %%
# we can use this to remove our foor loop 
is_long= imdb2.duration >=200
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: duration, dtype: bool

# %%
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: duration, dtype: bool

# %%
# now we will pass the boolean series in the imdb2 so that it will return the part which we want
imdb2[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
# it also work exactly the same
imdb2[imdb2.duration >=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %% [markdown]
# # Bonus Tip

# %%
# for getting the column out of our created dataframe
imdb2[imdb2.duration >=200].genre
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
# final point usage of loc it usually is the best method now days 2021 and powerfull
imdb2.loc[imdb2.duration >=200,'genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# # how to filter the dataframe by multiple filter criteria

# %%
imdb3 = pd.read_csv("http://bit.ly/imdbratings")

# %%
# u have to keep the order in parenthesis it the filteered data which we wanted to get 
# we have to use the & == and operator
imdb3[(imdb3.duration >= 200) & (imdb3.genre == 'Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
# for the the or conditon e use | 
# it will simply return the data which satisfy the one of the given condition 
imdb3[(imdb3.duration >= 200) | (imdb3.genre == 'Drama')]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 5            8.9                                   12 Angry Men
# 7            8.9  The Lord of the Rings: The Return of the King
# 9            8.9                                     Fight Club
# 13           8.8                                   Forrest Gump
# ..           ...                                            ...
# 958          7.4                             My Sister's Keeper
# 968          7.4                            The English Patient
# 970          7.4                                    Wonder Boys
# 972          7.4                                 Blue Valentine
# 973          7.4                          The Cider House Rules
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 5        NOT RATED      Drama        96
# 7            PG-13  Adventure       201
# ...

# %% [markdown]
# # Bonnu Tip

# %%
imdb3[(imdb3.duration == "Action") | (imdb3.genre == 'Drama') | (imdb3.genre == 'Crime')]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 5            8.9              12 Angry Men      NOT RATED  Drama        96
# ..           ...                       ...            ...    ...       ...
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 970          7.4               Wonder Boys              R  Drama       107
# 972          7.4            Blue Valentine          NC-17  Drama       112
# 973          7.4     The Cider House Rules          PG-13  Drama       126
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
# to simply shorten the above statment 
imdb3[imdb3.genre.isin(['Crime','Action',"Drama"])] # it is a function
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %% [markdown]
# # pandas questions

# %% [markdown]
# ### use nrows argument in pd.read_csv() to just get the number of rows u want

# %%
# to remove a particular dtype or in other words slecting a particular dtype
imdb3.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
import numpy as np 
imdb3.select_dtypes(include = [np.number]).dtypes
# Out:
# star_rating    float64
# duration         int64
# dtype: object

# %%
imdb3.select_dtypes(include = [np.number])
# Out:
#      star_rating  duration
# 0            9.3       142
# 1            9.2       175
# 2            9.1       200
# 3            9.0       152
# 4            8.9       154
# ..           ...       ...
# 974          7.4       116
# 975          7.4       118
# 976          7.4       138
# 977          7.4       114
# 978          7.4       126
#
# [979 rows x 2 columns]

# %%
# if u wanted to describe the particular dtypes just pass it in the form of a list
# if u want if for a particukllar column then pass it in the form string
imdb3.describe(include = ['object','float64'])
# Out:
#         star_rating                            title content_rating  genre  \
# count    979.000000                              979            976    979
# unique          NaN                              975             12     16
# top             NaN  The Girl with the Dragon Tattoo              R  Drama
# freq            NaN                                2            460    278
# mean       7.889785                              NaN            NaN    NaN
# std        0.336069                              NaN            NaN    NaN
# min        7.400000                              NaN            NaN    NaN
# 25%        7.600000                              NaN            NaN    NaN
# 50%        7.800000                              NaN            NaN    NaN
# 75%        8.100000                              NaN            NaN    NaN
# max        9.300000                              NaN            NaN    NaN
#
#                                               actors_list
# ...

# %% [markdown]
# # How do i use the axis parameter in pandas

# %%
drinks = pd.read_csv("http://bit.ly/drinksbycountry")

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# if u want to remove the column 
# if we not use the inplace parameter then the dataframe which we use is a temperory column 
drinks.drop(2,axis= 0).head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
# for any operation the pandas usualy consider the axis 0 as we wanna go down the column 
# 0 axis is the default axis and go along the row for creating the new dataframe which we wanna have a look 
# at 
# and  u can specify the axis "axis = 'index'" which will also output the same thing as the axis does in
# the operation part  
drinks.mean() # here the axis 0 means column wise but and 1 means row wise
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %% [markdown]
# # Bonus tip
# #### above comment part

# %% [markdown]
# # How do use the string method in pandas

# %%
ordersonline = pd.read_table("http://bit.ly/chiporders")

# %%
ordersonline.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
ordersonline.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %%
ordersonline[ordersonline.item_name.str.contains('Chicken')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# ...

# %% [markdown]
# # Bonus Tip

# %%
ordersonline.choice_description.str.replace('[',' ').str.replace(']',' ') # this return a pandas series
# Out:
# C:\Users\mynam\AppData\Local\Temp/ipykernel_10708/2012823960.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ordersonline.choice_description.str.replace('[',' ').str.replace(']',' ') # this return a pandas series
# 0                                                     NaN
# 1                                             Clementine
# 2                                                  Apple
# 3                                                     NaN
# 4        Tomatillo-Red Chili Salsa (Hot),  Black Beans...
#                               ...
# 4617     Fresh Tomato Salsa,  Rice, Black Beans, Sour ...
# 4618     Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...
# 4619     Fresh Tomato Salsa,  Fajita Vegetables, Pinto...
# 4620     Fresh Tomato Salsa,  Fajita Vegetables, Lettu...
# ...

# %%
# many pandas string accept a regular expresion
ordersonline.choice_description.str.replace('[\[\]]',' ') # first bracket is the character class
# Out:
# C:\Users\mynam\AppData\Local\Temp/ipykernel_10708/456046604.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   ordersonline.choice_description.str.replace('[\[\]]',' ') # first bracket is the character class
# 0                                                     NaN
# 1                                             Clementine
# 2                                                  Apple
# 3                                                     NaN
# 4        Tomatillo-Red Chili Salsa (Hot),  Black Beans...
#                               ...
# 4617     Fresh Tomato Salsa,  Rice, Black Beans, Sour ...
# 4618     Fresh Tomato Salsa,  Rice, Sour Cream, Cheese...
# 4619     Fresh Tomato Salsa,  Fajita Vegetables, Pinto...
# 4620     Fresh Tomato Salsa,  Fajita Vegetables, Lettu...
# 4621     Fresh Tomato Salsa,  Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %% [markdown]
# # How do i change the datatype of the pandas series

# %%
# see the screenshot in ur mobile

# %% [markdown]
# # when should  we use groupby in pandas

# %%
drank = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drank.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drank.beer_servings.mean() # to see the avrage of the whole dataset
# Out:
# 106.16062176165804

# %%
# what if we wanted to see the avrage of the this servings by continents
drank.groupby('continent').beer_servings.mean()
# its main use is to when we want to analyze any series by category
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
# how this actually works
drank[drank.continent =="Africa"].beer_servings.mean()
# Out:
# 61.471698113207545

# %% [markdown]
# drank.groupby('continent').beer_servings.agg(['max','min','mean','count']) # it helps us to specify different function like max,min,
# # mean

# %% [markdown]
# # Bonus Tip

# %%
drank.groupby('continent').mean() # mean for all of them at once
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# %matplotlib inline # it help us to appear matplotlib in the ipython notebook
# Out:
# UsageError: unrecognized arguments: # it help us to appear matplotlib in the ipython notebook

# %%
drank.groupby('continent').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continent'>

# %% [markdown]
# # how do i explore a pandas series

# %%
movies= pd.read_csv("http://bit.ly/imdbratings")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes # we will look on the two topics genre and duration
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.genre.describe() # frequency hamesha jo top me likha he uska hota he
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movies.genre.value_counts() # this is the new series on which we can run the function which we use on 
# series
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies.genre.value_counts(normalize=True) # turn this raw count into percentages
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
movies.genre.value_counts().head()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Name: genre, dtype: int64

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique()
# Out:
# 16

# %%
# doing  a cross tabulation generally used for categorical type of data 
pd.crosstab(movies.genre,movies.content_rating) # it gets tally with content_rating
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
movies.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
movies.duration.value_counts() # usefull in this case but for categorical data which we saw just above 
# then it is very useful
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
#        ..
# 67      1
# 195     1
# 76      1
# 66      1
# 205     1
# Name: duration, Length: 133, dtype: int64

# %% [markdown]
# # bonus Tip

# %%
movies.duration.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
movies.genre.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # how to handel missing values in panda dataset

# %%
ufos = pd.read_csv('http://bit.ly/uforeports')

# %%
ufos.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
ufos.isnull().tail() # it detect the null values and return true for a null values
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
ufos.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %%
ufos.isnull().sum() # here pandas is converting true to 1 and false to 0
# and the mathamatical operation the axis 0 defines the column remember
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
# we canpass the same thing like this to understand the null values of a particular given series 
ufos[ufos.City.isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %% [markdown]
# # what do with this missing values

# %%
ufos.shape
# Out:
# (18241, 5)

# %%
# Firstly we can simply drop the row in a givem dataset
# droping if any of its values are missing 
ufos.dropna(how='any').shape #it has inplace parameter as false as it does not directly changes the dataset
# Out:
# (2486, 5)

# %%
ufos.shape
# Out:
# (18241, 5)

# %%
# Secondly drop if only all of its valuers are missing 
ufos.dropna(how='all').shape
# Out:
# (18241, 5)

# %%
# we can use a list of column whcich we wanna consider 
ufos.dropna(subset= ['City','Shape Reported'],how= 'any').shape
# we use above to drop the row if any of the given parameter is missing
# Out:
# (15576, 5)

# %%
ufos.dropna(subset= ['City','Shape Reported'],how= 'all').shape
# only drop if all of the given parameter is missing
# Out:
# (18237, 5)

# %% [markdown]
# # bonus tip

# %%
ufos["Shape Reported"].fillna(value='VARIOUS',inplace=True)

# %%
# filling the missing values
ufos['Shape Reported'].value_counts(dropna=False) # we use dropna in this so too see how many missing 
#values are there in datset
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# DOME            1
# FLARE           1
# HEXAGON         1
# PYRAMID         1
# Name: Shape Reported, dtype: int64

# %% [markdown]
# # how to use index in pandas dataframe

# %%
#we can make parrticular column as the index
drinksx = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinksx.set_index('country',inplace = True)

# %%
drinksx.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinksx.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drinksx.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinksx.loc['Brazil','beer_servings']
# Out:
# 245

# %%
# if u want to remove that country head onn that index row 
drinksx.index.name = None

# %%
drinksx.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
#  to change the above changes 
drinksx.index.name = 'country'
drinksx.reset_index(inplace=True)

# %%
drinksx.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# the describe function give out a  dataframe 
drinksx.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %% [markdown]
# # Above part 2

# %%
drinksx.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
# want to see ot in array form then 
drinksx.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
drinksx.continent.value_counts()['Africa']
# Out:
# 53

# %%
drinksx.continent.value_counts().sort_values()
# Out:
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# Name: continent, dtype: int64

# %%
drinksx.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
people = pd.Series([3000000,85000],index = ["Albania",'Andorra'],name='Population')

# %%
people
# Out:
# Albania    3000000
# Andorra      85000
# Name: Population, dtype: int64

# %%
drinksx.set_index('country',inplace=True)

# %%
drinksx.index.name=None

# %%
# if i wanted to use the above data set  with this to calculate the total beer servings
drinksx.beer_servings
# Out:
# Afghanistan      0
# Albania         89
# Algeria         25
# Andorra        245
# Angola         217
#               ...
# Venezuela      333
# Vietnam        111
# Yemen            6
# Zambia          32
# Zimbabwe        64
# Name: beer_servings, Length: 193, dtype: int64

# %%
drinksx.beer_servings *people
# Out:
# Afghanistan            NaN
# Albania        267000000.0
# Algeria                NaN
# Andorra         20825000.0
# Angola                 NaN
#                   ...
# Venezuela              NaN
# Vietnam                NaN
# Yemen                  NaN
# Zambia                 NaN
# Zimbabwe               NaN
# Length: 193, dtype: float64

# %%
# if i want to add the people data with this the drinks dataframe
pd.concat([drinksx,people],axis=1).head() # ulsed to concatinate the the row and columns
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent  Population
# Afghanistan                           0.0      Asia         NaN
# Albania                               4.9    Europe   3000000.0
# Algeria                               0.7    Africa         NaN
# Andorra                              12.4    Europe     85000.0
# Angola                                5.9    Africa         NaN
